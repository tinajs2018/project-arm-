# %%
import pandas as pd
import statsmodels.api as sm

# %%
import pandas as pd

data = pd.read_csv('data - Sheet1.csv')

data.head()
# Out:
#   Country                      Subject Descriptor              Units  \
# 0   Kenya  Gross domestic product, current prices  National currency
# 1   Kenya  Gross domestic product, current prices       U.S. dollars
# 2   Kenya        Gross domestic product, deflator              Index
# 3   Kenya      Inflation, average consumer prices              Index
# 4   Kenya                              Population            Persons
#
#       Scale      2000      2001      2002      2003      2004      2005  ...  \
# 0  Billions  2017.111  2071.200  2199.746  2317.760  2451.566  2697.940  ...
# 1  Billions    26.480    26.363    27.934    30.523    30.964    35.709  ...
# 2       NaN    52.567    51.911    54.868    56.156    56.767    59.122  ...
# 3       NaN   100.000   105.824   108.106   114.574   124.176   133.890  ...
# 4  Millions    29.500    30.300    31.100    32.000    32.900    33.800  ...
#
#        2012      2013      2014      2015      2016      2017      2018  \
# ...

# %%
dependent_variable = "Real GDP per capita"  # Replace with the actual column name in your data
independent_variables = ["Inflation", "Exchange Rate", "Government Debt", "Government Revenue"]  # Replace with actual column names

# %%
model = sm.OLS(data[dependent_variable], data[independent_variables])
results = model.fit()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 model = sm.OLS(data[dependent_variable], data[independent_variables])
#       2 results = model.fit()
#
# TypeError: '_io.StringIO' object is not subscriptable

# %%
import pandas as pd
import statsmodels.api as sm

# Load data from CSV
data = pd.read_csv('data - Sheet1.csv')


# Define variables
dependent_variable = "Subject Descriptor"  # Replace with the actual column name
independent_variables = ["Inflation", "Exchange Rate", "Government Debt", "Government Revenue"]  # Replace with actual column names

# Create the model
model = sm.OLS(data[dependent_variable], data[independent_variables])
results = model.fit()

# Print the summary
print(results.summary())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 13
#      10 independent_variables = ["Inflation", "Exchange Rate", "Government Debt", "Government Revenue"]  # Replace with actual column names
#      12 # Create the model
# ---> 13 model = sm.OLS(data[dependent_variable], data[independent_variables])
#      14 results = model.fit()
#      16 # Print the summary
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
from io import StringIO
data_str = ",Country,Subject Descriptor,Units,Scale,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021\
0,Kenya,\"Gross domestic product, current prices\",National currency,Billions,2017.111,2071.2,2199.746,2317.76,2451.566,2697.94,3010.76,3394.984,3338.064,3275.642,3597.63,4162.514,4767.191,5311.322,6003.835,6884.317,7594.064,8483.396,9340.307,10255.654,10752.992,12019.078\
1,Kenya,\"Gross domestic product, current prices\",U.S. dollars,Billions,26.48,26.363,27.934,30.523,30.964,35.709,41.758,50.433,48.255,42.348,45.406,46.554,56.407,61.703,68.395,70.369,74.817,81.964,92.211,100.504,101.279,109.797\
2,Kenya,\"Gross domestic product, deflator\",Index,,52.567,51.911,54.868,56.156,56.767,59.122,62.329,65.777,64.524,61.096,62.098,68.348,74.856,80.349,86.484,94.474,100.0,107.605,112.161,117.309,123.388,128.62\
3,Kenya,\"Inflation, average consumer prices\",Index,,100.0,105.824,108.106,114.574,124.176,133.89,141.978,148.033,170.388,188.367,196.484,224.036,245.046,259.056,276.874,295.099,313.742,338.794,354.683,373.139,392.879,416.881"
data = StringIO(data_str)
df = pd.read_csv(data, header=0)
# Selecting relevant data for regression analysis
gdp_usd = df.iloc[1, 5:].astype(float).values
inflation = df.iloc[3, 5:].astype(float).values
years = np.arange(2000, 2022)
# Performing linear regression
X = inflation.reshape(-1, 1)
y = gdp_usd
model = LinearRegression()
model.fit(X, y)
y_pred = model.predict(X)
# Calculating R-squared value
r2 = r2_score(y, y_pred)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 15
#      13 df = pd.read_csv(data, header=0)
#      14 # Selecting relevant data for regression analysis
# ---> 15 gdp_usd = df.iloc[1, 5:].astype(float).values
#      16 inflation = df.iloc[3, 5:].astype(float).values
#      17 years = np.arange(2000, 2022)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1097, in _LocationIndexer.__getitem__(self, key)
#    1095     if self._is_scalar_access(key):
#    1096         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#    1100     axis = self.axis or 0
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1594, in _iLocIndexer._getitem_tuple(self, tup)
# ...

# %%
import pandas as pd
import statsmodels.api as sm
data = pd.read_csv('data - Sheet1.csv')
# Assuming your data is in a CSV file named "your_data.csv"
try:
  # Load data from CSV with header row (adjust as needed)
  data = pd.read_csv("data - Sheet1.csv", header=0)
except FileNotFoundError:
  print("Error: Data file 'your_data.csv' not found. Please check the file path.")
  exit()

# Define variables based on column names (replace with actual names)
dependent_variable = "Country"
independent_variables = ["Inflation", "Exchange Rate", "Government Debt", "Government Revenue"]

# Check for missing values (optional)
if data.isnull().values.any():
  print("Warning: Your data contains missing values. Consider handling them (e.g., imputation) before proceeding.")

try:
  # Select relevant data (handle potential IndexError)
  gdp_usd = data[dependent_variable].astype(float).values
  inflation = data[independent_variables[0]].astype(float).values
  exchange_rate = data[independent_variables[1]].astype(float).values
  govt_debt = data[independent_variables[2]].astype(float).values
  govt_revenue = data[independent_variables[3]].astype(float).values

except IndexError:
  print("Error: Indexing issue with the DataFrame. Check column names and data structure.")
  exit()

# Create the model and fit the regression
model = sm.OLS(gdp_usd, sm.add_constant(np.column_stack([inflation, exchange_rate, govt_debt, govt_revenue])))
results = model.fit()

# Print the summary of the regression analysis
print(results.summary())
# Out:
# ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 22
#      18   print("Warning: Your data contains missing values. Consider handling them (e.g., imputation) before proceeding.")
#      20 try:
#      21   # Select relevant data (handle potential IndexError)
# ---> 22   gdp_usd = data[dependent_variable].astype(float).values
#      23   inflation = data[independent_variables[0]].astype(float).values
#      24   exchange_rate = data[independent_variables[1]].astype(float).values
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# ...
